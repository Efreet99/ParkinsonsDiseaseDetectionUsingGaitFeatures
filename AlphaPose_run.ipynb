# %% [markdown]
# **Install the necessary packages**

# %%
! pip install pyyaml==5.4.1
! pip install scipy==1.8.0
! pip install torch==2.0.0 torchvision==0.15.1
! pip install pillow==9.5.0
! pip install -U -q PyDrive
! python -m pip install cython
! sudo apt-get install libyaml-dev
! pip install cython_bbox
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libyaml-dev is already the newest version (0.2.2-1).
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# **Mount Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Clone AlphaPose from GitHub**

# %%
import os
os.chdir('/content/drive/MyDrive/FYP_Phase2/OoiWeiXiang_1181202928')
# !git clone https://github.com/MVIG-SJTU/AlphaPose.git
# Out:
# fatal: destination path 'AlphaPose' already exists and is not an empty directory.

# %% [markdown]
# **Get AlphaPose installed on your Google Drive**

# %%
import os
os.chdir('/content/drive/MyDrive/FYP_Phase2/OoiWeiXiang_1181202928/AlphaPose')
! python setup.py build develop
# Out:
# /usr/local/lib/python3.9/dist-packages/setuptools/__init__.py:84: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
# !!
#
#         ********************************************************************************
#         Requirements should be satisfied by a PEP 517 installer.
#         If you are using pip, you can try `pip install --use-pep517`.
#         ********************************************************************************
#
# !!
#   dist.fetch_build_eggs(dist.setup_requires)
# running build
# running build_py
# creating build
# creating build/lib.linux-x86_64-3.9
# creating build/lib.linux-x86_64-3.9/alphapose
# copying alphapose/__init__.py -> build/lib.linux-x86_64-3.9/alphapose
# copying alphapose/opt.py -> build/lib.linux-x86_64-3.9/alphapose
# copying alphapose/version.py -> build/lib.linux-x86_64-3.9/alphapose
# creating build/lib.linux-x86_64-3.9/trackers
# copying trackers/__init__.py -> build/lib.linux-x86_64-3.9/trackers
# ...

# %% [markdown]
# **Authenticate and create the PyDrive client**

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# Authenticate and create the PyDrive client.
# This only needs to be done once per notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %% [markdown]
# **You only need to run this once to save the models and the config to your Drive**

# %%
os.chdir('/content/drive/MyDrive/FYP_Phase2/OoiWeiXiang_1181202928/AlphaPose/detector/yolo')
! mkdir data
file_id = '1XutlUBOZirbzxx8mI-ra0Rt2BW7LKnaz'
downloaded = drive.CreateFile({'id': file_id})
downloaded.GetContentFile('/content/drive/MyDrive/FYP_Phase2/OoiWeiXiang_1181202928/AlphaPose/detector/yolo/data/yolov3-spp.weights')

os.chdir('/content/drive/MyDrive/FYP_Phase2/OoiWeiXiang_1181202928/AlphaPose/detector/tracker')
! mkdir data
file_id = '1Y-2TKTeueIfZY77RY2GsF4d0JLLC-0Pu'
downloaded = drive.CreateFile({'id': file_id})
downloaded.GetContentFile('/content/drive/MyDrive/FYP_Phase2/OoiWeiXiang_1181202928/AlphaPose/detector/tracker/data/JDE-1088x608-uncertainty')

file_ids = [
            {'id': '1Y05Q8VhJgx9QYxh5OsS2AdQVN6_6GIvL',
             'name': 'fast_res50_256x192.pth'},
            {'id': '1Y31pvfgxkXUJk6ZN7EU6oOWMte0wxv_M',
             'name': 'halpe136_fast_res50_256x192.pth'}
           ] 
for file_id in file_ids:
  downloaded = drive.CreateFile({'id': file_id['id']})
  downloaded.GetContentFile('/content/drive/MyDrive/FYP_Phase2/OoiWeiXiang_1181202928/AlphaPose/pretrained_models/{}'.format(file_id['name']))
# Out:
# mkdir: cannot create directory ‘data’: File exists
# mkdir: cannot create directory ‘data’: File exists

# %% [markdown]
# **Process videos in a folder in bulk**
#
# *   All the videos you want to process should be in a single folder.
# *   On the file directory on the left pane, navigate to that folder.
# *   Right-click, click on "copy path".
# *   Paste the copied path at the indicated point in the cell below
# *   Run the cell and wait for all the videos to be processed.
#
# For example, if your videos are in content/drive/MyDrive/videos:
#
# ```
# ! sh run_all.sh content/drive/MyDrive/videos
# ```
#
# *   Ensure there are no spaces in your path.
# *   Ensure there are no spaces in the video filenames.
#
# Move your videos to another folder in your drive if necessary.
#
# The output will be in the **output** folder in AlphaPose.

# %%
import os
os.chdir('/content/drive/MyDrive/FYP_Phase2/OoiWeiXiang_1181202928/AlphaPose')

# EDIT THE LINE BELOW TO ADD THE PATH TO YOUR VIDEOS
# !sh run_all.sh /content/drive/MyDrive/FYP_Phase2/OoiWeiXiang_1181202928/Cropped
# Out:
# Gathering video files
# Video path: /content/drive/MyDrive/FYP_Phase2/OoiWeiXiang_1181202928/Cropped/severe_youtube_10012022_3.mp4
# mkdir: cannot create directory ‘output/severe_youtube_10012022_3.mp4’: File exists
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/FYP_Phase2/OoiWeiXiang_1181202928/AlphaPose/scripts/demo_inference.py", line 14, in <module>
#     from trackers.tracker_api import Tracker
#   File "/content/drive/MyDrive/FYP_Phase2/OoiWeiXiang_1181202928/AlphaPose/trackers/tracker_api.py", line 21, in <module>
#     from utils.utils import *
#   File "/content/drive/MyDrive/FYP_Phase2/OoiWeiXiang_1181202928/AlphaPose/trackers/utils/utils.py", line 7, in <module>
#     import cv2
# ModuleNotFoundError: No module named 'cv2'
# Video path: /content/drive/MyDrive/FYP_Phase2/OoiWeiXiang_1181202928/Cropped/severe_youtube_10012022_4.mp4
# mkdir: cannot create directory ‘output/severe_youtube_10012022_4.mp4’: File exists
# Traceback (most recent call last):
# ...
